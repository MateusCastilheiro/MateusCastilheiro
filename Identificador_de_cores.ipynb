# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusCastilheiro/MateusCastilheiro/blob/main/Identificador_de_cores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python matplotlib

# %%
import cv2
import matplotlib.pyplot as plt

image_path = '/content/laranja 0,5%.jfif'
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.show()

# %%
x, y = 1000, 500  # Replace with the desired pixel coordinates
(r, g, b) = image_rgb[y, x]
print("R={}, G={}, B={}".format(r, g, b))
# Out:
# R=239, G=154, B=73

# %%
import numpy as np

color_patch = np.zeros((50, 50, 3), dtype=np.uint8)
color_patch[:, :] = (r, g, b)

plt.imshow(color_patch)
plt.show()
